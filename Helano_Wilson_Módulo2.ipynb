# %% [markdown]
# <a href="https://colab.research.google.com/github/HWP-Wilson/Analise_da_adesao_as_vacinas_no_Brasil/blob/main/Helano_Wilson_M%C3%B3dulo2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**A descoberta da vacina (Covid-19) vai resolver a pandemia no Brasil?**
#
# helanowilson@ufc.br

# %% [markdown]
# ## INTRODUÇÃO

# %% [markdown]
# As vacinas para combater a Covid-19 estão em suas fases finais. Quase disponiveis. No entanto, não existe ainda condições de vacinar toda a população mundial. Muitos paises estão planejando e organizando as metas de vacinação. O que é consenso mundial é a necessidade de imunizar primeiramente os idosos. No Brasil existe um movimento forte contra a obrigatoriedade da vacina e isso se reflete ao longo dos anos quando se analisa a Cobertura Vacinal.

# %% [markdown]
# ![adesao vacina.png](data:image/png;base64,...)

# %% [markdown]
# É possível analisar pelos anos anteriores a adesão a vacina da Covid?

# %% [markdown]
# ## A vacina será dada prioritariamente ao grupo de maior risco: idosos. Comparando a adesão a duas vacinas BCG (publico alvo recém nascido) e pneumocócica (que inclui os idosos).

# %%
# Montando o Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
###Importação de bibliotecas para exploração de dados
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# %matplotlib inline

# %%
###Baixando arquivos 
pneumonia = pd.read_csv('/content/drive/MyDrive/Helano_Wilson_Projeto2_bootcampAlura/A125516189_28_143_208.csv', encoding = "ISO-8859-1",
                    skiprows=4, sep =';', skipfooter = 20,thousands= ".", decimal =",")
BCG = pd.read_csv('/content/drive/MyDrive/Helano_Wilson_Projeto2_bootcampAlura/A133943189_28_143_208.csv', encoding = "ISO-8859-1",
                    skiprows=4, sep =';', skipfooter = 20,thousands= ".", decimal =",")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """

# %%
pneumonia
# Out:
#     Ano  1 Região Norte  ...  5 Região Centro-Oeste  Total
# 0  2010            8.22  ...                  21.61  24.02
# 1  2011           59.41  ...                  87.40  81.65
# 2  2012           77.07  ...                  91.49  88.39
# 3  2013           79.66  ...                 101.60  93.57
# 4  2014           76.56  ...                 101.42  93.45
# 5  2015           75.00  ...                  92.76  94.23
# 6  2016           85.80  ...                 104.59  95.00
# 7  2017           83.80  ...                  93.18  91.56
# 8  2018           85.95  ...                  93.94  93.43
# 9  2019           54.49  ...                  56.91  54.43
#
# [10 rows x 7 columns]

# %%
pneumonia.set_index('Ano', inplace=True)

# %%
BCG
# Out:
#      Ano  1 Região Norte  ...  5 Região Centro-Oeste   Total
# 0   2008          120.07  ...                 112.53  108.91
# 1   2009          120.59  ...                 111.74  108.71
# 2   2010          117.45  ...                 110.61  106.71
# 3   2011          115.70  ...                 110.17  107.94
# 4   2012          113.64  ...                 108.99  105.69
# 5   2013          113.18  ...                 116.86  107.42
# 6   2014          114.13  ...                 116.90  107.28
# 7   2015          103.72  ...                 105.44  105.08
# 8   2016           92.05  ...                 104.13   95.55
# 9   2017           92.07  ...                  96.37   97.12
# 10  2018           93.03  ...                  97.85   97.72
# 11  2019           54.50  ...                  58.67   52.95
#
# [12 rows x 7 columns]

# %%
BCG.set_index('Ano', inplace=True)

# %% [markdown]
# ##Gráfico comparativo da Cobertura Vacinal entre BCG e Pneumocócica

# %%
plt.figure(figsize=(18, 10))
s1 = plt.subplot(2, 2, 1)
#Gastos Total do governo federal
s1 = BCG['Total'].plot( kind ="bar", color = 'red')
plt.title('BCG - Cobertura vacinal (---- Meta do Governo 95%)')
plt.xlabel('')
plt.yticks([0, 20, 40, 60, 80, 100, 115])


plt.ylabel('Cobertura Vacinal %')
plt.axhline(y=95, color ='black', linestyle = "dashed", xmin=0.0, xmax=1)


s2 = plt.subplot(2, 2, 2)
s2 = pneumonia['Total'].plot(kind ="bar",color="red")
plt.title('Pneumocócica - Cobertura Vacinal (---- Meta do Governo 95%) ')
plt.yticks([0, 20, 40, 60, 80, 100, 115])
plt.xlabel('')
plt.ylabel('Cobertura Vacinal %')
plt.axhline(y=95, color ='black', linestyle = "dashed", xmin=0.0, xmax=1)

# %% [markdown]
# 1. Fica evidente a menor adesão a vacina em relação a faixa etária mais avançada. A BCG é aplicada diretamente na maternidade, isso justifica uma maior adesão. Já nos idosos a procura por vacina é menor.

# %% [markdown]
# 2. A adesão até mesmo da BCG mantem uma tendência de queda ao longo dos anos. O ano de 2019 consta apenas dados até setembro daquele ano, naturalmente para ambas as vacinas houve queda em relação ao ano de 2018. No entanto, comparado ao mesmo periodo de 2018, a adesão em 2019 estava menor para o mesmo periodo.

# %% [markdown]
# 3. De acordo com o gráfico abaixo, retirado do projeto 1 (Helano Wilson, BootCamp Alura), nota-se a correlação positiva entre a taxa de mortalidade no SUS e a porcentagem de idosos na população. O que torna mais preocupante se no grupo de risco (idosos) não for atingido a meta da CV pelo governo.

# %% [markdown]
# ![idosos.png](data:image/png;base64,...)

# %% [markdown]
# ## CONCLUSÃO
# * Pode-se concluir, numa análise bem simples e direta, que o governo federal deve se mobilizar de forma contundente em conscientizar a população a aderir a vacina. Do contrário, percebe-se pelos anos anteriores que teremos baixa adesão a vacina. Nosso presidente já citou várias vezes ser contra a obrigatoriedade da vacina e levantou questionamentos sobre os benefícios e interesses dos países que estão produzindo as vacinas.
#
# * A adesão dos idosos é fundamental para a diminuição da taxa de mortalidade. A conscientização dos muitos adultos que cuidam desses idosos é mais que importante. Em geral o governo deve ser eficaz em campanhas de conscientização.
#
# * O estudo aqui levantado não trás uma análise e estudo de quem domina o python com experiencia e tem como objetivo mostrar que, mesmo iniciantes a Cientista de Dados, podemos fazer análises e apresentar resultados de interesse da sociedade.
